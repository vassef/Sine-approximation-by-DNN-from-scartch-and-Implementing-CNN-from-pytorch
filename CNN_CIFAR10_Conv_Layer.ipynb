# %%
# import libraries
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import time
# for importing data
import torchvision
import torchvision.transforms as T
from torch.utils.data import DataLoader,Subset

import matplotlib.pyplot as plt
from IPython import display
display.set_matplotlib_formats('svg')

# %%
# use GPU if available
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Import a dataset

# %%
# transformations
transform = T.Compose([ T.ToTensor(),
                        T.Normalize([.5,.5,.5],[.5,.5,.5])
                       ])

# import the data and simultaneously apply the transform
trainset = torchvision.datasets.CIFAR10(root='./data', train=True,  download=True, transform=transform)
devtest  = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)

# split the devtest into two separate sets
randidx = np.random.permutation(10000)   # a random permutation of indices
devset  = Subset(devtest,randidx[:6000]) # Subset for devset
testset = Subset(devtest,randidx[6000:]) # Subset for test

# transform to dataloaders
batchsize    = 32
train_loader = DataLoader(trainset,batch_size=batchsize,shuffle=True,drop_last=True)
dev_loader   = DataLoader(devset,  batch_size=batchsize) # note: devtest in batches!
test_loader  = DataLoader(testset, batch_size=len(testset))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# check out the shape of the datasets
print('Data shapes (train/dev/test):')
print( len(trainset) )
print( len(devset) )
print( len(testset) )

#the range of pixel intensity values
print('\nData value range:')
print( (np.min(trainset.data),np.max(trainset.data)) )

# the unique categories
print('\nData categories:')
print( trainset.classes )
# Out:
# Data shapes (train/dev/test):
# 50000
# 6000
# 4000
#
# Data value range:
# (0, 255)
#
# Data categories:
# ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# %%
#Check out
X,y = next(iter(train_loader))

# shape of one batch of train_set
print('Data shapes (train/test):')
print( X.data.shape )

#range of pixel intensity values
print('\nData value range:')
print( (torch.min(X.data),torch.max(X.data)) )
# Out:
# Data shapes (train/test):
# torch.Size([32, 3, 32, 32])
#
# Data value range:
# (tensor(-1.), tensor(1.))

# %%
# inspect a few random images

fig,axs = plt.subplots(4,4,figsize=(10,10))

for (i,ax) in enumerate(axs.flatten()):

  # extract that image (need to transpose it back to 32x32x3)
  pic = X.data[i].numpy().transpose((1,2,0))
  pic = pic/2 + .5 # undo normalization
  
  # label
  label = trainset.classes[y[i]]

  # show!
  ax.imshow(pic)
  ax.text(16,0,label,ha='center',fontweight='bold',color='k',backgroundcolor='y')
  ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Create the DL model

# %%
# create a class for the model
def makeTheNet(nLayers,printtoggle=False):

  class cnnnet(nn.Module):
    def __init__(self,nLayers,printtoggle):
      super().__init__()
      #Creat a dictionary
      self.conv = nn.ModuleDict()
      self.bnorms=nn.ModuleDict()
      self.nLayers = nLayers
      # print toggle
      self.print = printtoggle

      ### -------------- feature map layers -------------- ###
      # first convolution layer
      self.conv1  = nn.Conv2d(3,64,3,padding=1)
      self.bnorm1 = nn.BatchNorm2d(64) # input the number of channels in this layer
      output_size=16 #(32+2*1-3)/1 + 1 = 32/2 = 16 (/2 b/c maxpool)
      if nLayers>=2:
        for i in range(2,nLayers+1):
          self.conv[f'conv{i}']=nn.Conv2d(64*(i-1),128*(i-1),3)
          self.bnorms[f'batchnorm{i}']=nn.BatchNorm2d(128*(i-1))
          output_size=np.round(((output_size-3)+1)/2).astype('int')#((num_previous_pixels-3)/1 + 1)/2 (/2 b/c maxpool)
        ### -------------- linear decision layers -------------- ###
        self.fc1 = nn.Linear(output_size*output_size*128*(nLayers-1),128*(nLayers-1))
        self.fc2 = nn.Linear(128*(nLayers-1),64)
        self.fc3 = nn.Linear(64,10)
      else :
        self.fc1 = nn.Linear(output_size*output_size*64,64)
        self.fc2 = nn.Linear(64,64)
        self.fc3 = nn.Linear(64,10)

    def forward(self,x):
      
      if self.print: print(f'Input: {list(x.shape)}')
      
      # first block: convolution -> maxpool -> batchnorm -> relu
      x = F.max_pool2d(self.conv1(x),2)
      x = F.leaky_relu(self.bnorm1(x))
      if self.print: print(f'First CPBR block: {list(x.shape)}')
      #Setting blocks :  convolution -> maxpool -> batchnorm -> relu
      for j in range(2,self.nLayers+1):
        x = F.max_pool2d(self.conv[f'conv{j}'](x),2)
        x = F.leaky_relu(self.bnorms[f'batchnorm{j}'](x))
        if self.print: print(f'Second CPR block: {list(x.shape)}')
      # reshape for linear layer
      nUnits = x.shape.numel()/x.shape[0]
      x = x.view(-1,int(nUnits))
      if self.print: print(f'Vectorized: {list(x.shape)}')
      # linear layers
      x = F.leaky_relu(self.fc1(x))
      x = F.dropout(x,p=.5,training=self.training)
      x = F.leaky_relu(self.fc2(x))
      x = F.dropout(x,p=.5,training=self.training) # training=self.training means to turn off during eval mode
      x = self.fc3(x)
      if self.print: print(f'Final output: {list(x.shape)}')

      return x

  # create the model instance
  net = cnnnet(nLayers,printtoggle)
  
  # loss function
  lossfun = nn.CrossEntropyLoss()

  # optimizer
  optimizer = torch.optim.Adam(net.parameters(),lr=.001,weight_decay=1e-5)

  return net,lossfun,optimizer

# %%
# test the model with one batch
net,lossfun,optimizer = makeTheNet(3,True)

X,y = iter(train_loader).next()
yHat = net(X)

# check size of output
print('\nOutput size:')
print(yHat.shape)

#compute the loss
loss = lossfun(yHat,torch.squeeze(y))
print(' ')
print('Loss:')
print(loss)
# Out:
# Input: [32, 3, 32, 32]
# First CPBR block: [32, 64, 16, 16]
# Second CPR block: [32, 128, 7, 7]
# Second CPR block: [32, 256, 2, 2]
# Vectorized: [32, 1024]
# Final output: [32, 10]
#
# Output size:
# torch.Size([32, 10])
#
# Loss:
# tensor(2.3669, grad_fn=<NllLossBackward0>)

# %%
from torchsummary import summary
summary(net.to(device),(3,32,32),batch_size=32)
# Out:
# Input: [2, 3, 32, 32]
# First CPBR block: [2, 64, 16, 16]
# Second CPR block: [2, 128, 7, 7]
# Second CPR block: [2, 256, 2, 2]
# Vectorized: [2, 1024]
# Final output: [2, 10]
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [32, 64, 32, 32]           1,792
#        BatchNorm2d-2           [32, 64, 16, 16]             128
#             Conv2d-3          [32, 128, 14, 14]          73,856
#        BatchNorm2d-4            [32, 128, 7, 7]             256
#             Conv2d-5            [32, 256, 5, 5]         295,168
#        BatchNorm2d-6            [32, 256, 2, 2]             512
#             Linear-7                  [32, 256]         262,400
#             Linear-8                   [32, 64]          16,448
#             Linear-9                   [32, 10]             650
# ================================================================
# Total params: 651,210
# Trainable params: 651,210
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.38
# Forward/backward pass size (MB): 29.55
# Params size (MB): 2.48
# Estimated Total Size (MB): 32.41
# ----------------------------------------------------------------

# %% [markdown]
# # Create a function that trains the model

# %%
# number of epochs
numepochs = 10
# a function that trains the model
def funtion2trainTheModel(nLayers):

  # create a new model
  net,lossfun,optimizer = makeTheNet(nLayers,False)

  # send the model to the GPU
  net.to(device)

  # initialize losses
  trainLoss = torch.zeros(numepochs)
  devLoss   = torch.zeros(numepochs)
  trainAcc  = torch.zeros(numepochs)
  devAcc    = torch.zeros(numepochs)


  # loop over epochs
  for epochi in range(numepochs):

    # loop over training data batches
    net.train() # switch to train mode
    batchLoss = []
    batchAcc  = []
    for X,y in train_loader:

      # push data to GPU
      X = X.to(device)
      y = y.to(device)

      # forward pass and loss
      yHat = net(X)
      loss = lossfun(yHat,y)

      # backprop
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()

      # loss and accuracy from this batch
      batchLoss.append(loss.item())
      batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
    # end of batch loop...

    # get average losses and accuracies across the batches
    trainLoss[epochi] = np.mean(batchLoss)
    trainAcc[epochi]  = 100*np.mean(batchAcc)


    #### test performance (done in batches!)
    net.eval() # switch to test mode
    batchAcc  = []
    batchLoss = []
    for X,y in dev_loader:

      # push data to GPU
      X = X.to(device)
      y = y.to(device)

      # forward pass and loss
      with torch.no_grad():
        yHat = net(X)
        loss = lossfun(yHat,y)
      
      # loss and accuracy from this batch
      batchLoss.append(loss.item())
      batchAcc.append( torch.mean((torch.argmax(yHat,axis=1) == y).float()).item() )
    # end of batch loop...

    # get average losses and accuracies across the batches
    devLoss[epochi] = np.mean(batchLoss)
    devAcc[epochi]  = 100*np.mean(batchAcc)

  # end epochs

  # function output
  return trainLoss,devLoss,trainAcc,devAcc,net

# %% [markdown]
# # Run the model and show the results!

# %%
# ~16 minutes with 10 epochs on GPU
numLayers = [1,2,3]
trainAcc= np.zeros((numepochs,len(numLayers)))
trainLoss= np.zeros((numepochs,len(numLayers)))
devAcc = np.zeros((numepochs,len(numLayers)))
devLoss=np.zeros((numepochs,len(numLayers)))
comptime = np.zeros(len(numLayers))

for ai,Layer in enumerate(numLayers):
  starttime = time.process_time()
  trainLoss[:,ai],devLoss[:,ai],trainAcc[:,ai],devAcc[:,ai],net = funtion2trainTheModel(Layer)
  comptime[ai] = time.process_time() - starttime
  print("Done by Number of Layers = {}".format(Layer))
  

fig,ax = plt.subplots(1,4,figsize=(20,8))

ax[0].plot(trainAcc)
ax[0].set_title('Train accuracy')
ax[1].plot(devAcc)
ax[1].set_title('Dev accuracy')
ax[2].plot(trainLoss)
ax[2].set_title('Train Losses')
ax[3].plot(devLoss)
ax[3].set_title('Dev Losses')
# common features
for i in range(2):
  ax[i].legend(numLayers)
  ax[i].set_xlabel('Epoch')
  ax[i].set_ylabel('Accuracy (%)')
  ax[i].set_ylim([50,100])
  ax[i].grid()
for i in range(2,4):
  ax[i].legend(numLayers)
  ax[i].set_xlabel('Epoch')
  ax[i].set_ylabel('Losses')
  ax[i].grid()

plt.show()



# bar plot of computation time
plt.bar(range(len(comptime)),comptime,tick_label=numLayers)
plt.xlabel('Number of Layers size')
plt.ylabel('Computation time (s)')
plt.show()
#trainLoss,devLoss,trainAcc,devAcc,net = funtion2trainTheModel()
# Out:
# Begin with Number of Layers = 1
# Begin with Number of Layers = 2
# Begin with Number of Layers = 3

# %%
#Finding the best number of layers by validation set
best_n_layer=3
## the real test set
trainLoss,devLoss,trainAcc,devAcc,net = funtion2trainTheModel(best_n_layer)
net.eval() # switch to test mode
X,y = next(iter(test_loader))

# push data to GPU
X = X.to(device)
y = y.to(device)

# forward pass and loss
with torch.no_grad():
  yHat = net(X)
  loss = lossfun(yHat,y)

# loss and accuracy from this batch
testLoss = loss.item()
testAcc  = 100*torch.mean((torch.argmax(yHat,axis=1) == y).float()).item()

# %%
fig,ax = plt.subplots(1,2,figsize=(16,5))

ax[0].plot(trainLoss,'s-',label='Train')
ax[0].plot(devLoss,'o-',label='Dev')
ax[0].plot(len(devLoss)-1,testLoss,'r*',markersize=15,label='Test')
ax[0].set_xlabel('Epochs')
ax[0].set_ylabel('Loss (CEL)')
ax[0].set_title('Model loss')

ax[1].plot(trainAcc,'s-',label='Train')
ax[1].plot(devAcc,'o-',label='Dev')
ax[1].plot(len(devAcc)-1,testAcc,'r*',markersize=15,label='Test')
ax[1].set_xlabel('Epochs')
ax[1].set_ylabel('Accuracy (%)')
ax[1].set_title(f'Final model dev/test accuracy: {devAcc[-1]:.2f}/{testAcc:.2f}%')
ax[1].legend()

plt.show()

# %%
import sklearn.metrics as skm
test_metrics  = [0,0,0,0]
# test
y = y.to('cpu')
yHat=yHat.to('cpu')
test_predictions = torch.argmax(yHat,axis=1)
test_predictions
test_metrics[0] = skm.accuracy_score (y,test_predictions)
test_metrics[1] = skm.precision_score(y,test_predictions,average='weighted')
test_metrics[2] = skm.recall_score   (y,test_predictions,average='weighted')
test_metrics[3] = skm.f1_score       (y,test_predictions,average='weighted')
#new plot
plt.bar(np.arange(4)+.1,test_metrics,.5)
plt.xticks([0,1,2,3],['Accuracy','Precision','Recall','F1-score'])
plt.ylim([.7,1])
plt.legend(['Test'])
plt.title('Performance metrics for NLayers : {}'.format(best_n_layer))
#new plot
precision = skm.precision_score(y,test_predictions,average=None)
recall    = skm.recall_score   (y,test_predictions,average=None)
fig = plt.figure(figsize=(12,3))
plt.bar(np.arange(10)-.15,precision,.5)
plt.bar(np.arange(10)+.15,recall,.5)
plt.xticks(range(10),range(10))
plt.ylim([.4,1])
plt.xlabel('Class')
plt.legend(['Precision','Recall'])
plt.title('Category-specific performance metrics for NLayers : {}'.format(best_n_layer))
#fig.suptitle('Mini Batch of size : {}'.format(batchsizes[bi]))
plt.tight_layout()
# Confusion matrices
testConf  = skm.confusion_matrix(y,test_predictions,normalize='true')
# confmat during TEST
fig = plt.figure(figsize=(12,3))
a = plt.imshow(testConf,cmap='Blues',vmax=.05)
plt.xticks(range(10))
plt.yticks(range(10))
plt.title('TEST confusion matrix for NLayers : {}'.format(best_n_layer))
plt.xlabel('Predicted Class')
plt.ylabel('True Class')
fig.colorbar(a)
#fig.suptitle('Mini Batch of size : {}'.format(batchsizes[bi]))
plt.tight_layout()
plt.show()
